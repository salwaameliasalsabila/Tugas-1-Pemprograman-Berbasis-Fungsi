# %% [markdown]
# #### **TUGAS 1 PEMPROGRAMAN BERBASIS FUNGSI**
#
# NAMA : Salwa Amelia Salsabila \
# NIM : 121450023 \
# KELAS RC
#
# **Soal 1**
#
# 1.a. Jelaskan menggunakan tabel mengenai kelebihan dan kekurangan paradigma procedural
# dibandingkan dengan object oriented (minimal 3)?
#
# **jawab**
#
# ![image.png](attachment:80037828-fa74-4957-a1cf-6a563f58dd01.png)
#
# ![image.png](attachment:1aaebba0-5e43-44e2-a522-07a11b376c86.png)
#
# 1.b. Jelaskan menggunakan tabel mengenai kelebihan dan kekurangan paradigma object
# oriented dibandingkan dengan functional (minimal 3)?
#
# **jawab**
#
# ![image.png](attachment:63c7acc0-ba7e-4b20-b251-dacee59b104c.png)
#
# ![image.png](attachment:7905875f-dfa5-4f37-9d53-789863e23003.png)
#
# 1.c. Jelaskan menggunakan tabel mengenai kelebihan dan kekurangan paradigma procedural
# dibandingkan dengan functional (minimal 3)?
#
# **jawab**
#
# ![image.png](attachment:59c5a94b-ed38-442c-bf4f-0329d265e57e.png)
#
# ![image.png](attachment:5059bc78-0e01-46d5-8ec6-598a46b86776.png)

# %% [markdown]
# **Soal 2**
#
# 2.a. Apa yang dimaksud dengan pure functional programming language?
#
# **jawab**
#
# fungsi yang melakukan suatu operasi yang hasilnya hanya bergantung dari input fungsi tersebut.
#
# 2.b. Dari bahasa pemrograman FP di slide sebelumnya ( slide 14 ) , manakah yang termasuk
# pure functional programming language?
#
# **jawab**
#
# Haskell adalah bahasa pemrograman fungsional murni.

# %% [markdown]
# **Soal 3**
#
# Simple Password encryption
# Seorang user dari sebuah website ingin meningkatkan security dari password yang dia miliki dengan metode
# mengubah password nya menjadi bentuk lain dengan beberapa aturan enkripsi sebagai berikut:
# 1. Input password bertipe string dengan batasan panjang password 100 karakter
# 2. Setiap karakter dari string tersebut diubah menjadi ASCII value
# 3. Kemudian setiap ASCII value tersebut dikembangkan menjadi 3 value dengan dilakukan operasi berikut: \
# a. Value pertama dibagi dengan integer 26 kemudian dibulatkan dan dijumlahkan dengan 80
# kemudian diubah kembali menjadi karakter \
# b. Value kedua dihitung sisa bagi dengan 26 kemudian dijumlahkan dengan 80 kemudian diubah
# kembali menjadi karakter \
# c. Value ketiga adalah karakter ‘+’ jika value pertama lebih besar dari value kedua, atau value ketiga
# adalah karakter ‘-’ jika value pertama tidak lebih besar dari value kedua
# 4. Deretkan value pertama, kedua dan ketiga untuk setiap karakter dalam password tersebut sehingga
# didapatkan password dalam bentuk baru
#
# 3.a. Bantulah user tersebut dengan membuatkan sebuah program yang secara otomatis
# mengubah password yang di input menjadi terenkripsi sesuai aturan tersebut!
#
# **jawab**

# %%
# Metode paradigma fungsional 
# Encrypt : proses teknis yang mengonversikan informasi menjadi kode rahasia, sehingga mengaburkan data yang Anda kirim, terima, atau simpan.
def encrypt(pswd):
    if len(pswd) == 0 or len(pswd) > 100:
        print("Maaf, tolong masukan password dengan benar (dengan rentang 1 - 100)")
    else : 
        change_ascii = [str(ord(i)) for i in pswd]
        open_decrypt = ''.join(chr((int(j)//26)+80)+chr((int(j)%26)+80)+('+' if (int(j)//26)+80 > (int(j)%26)+80 else '-') for j in change_ascii)
        # outputnya 
        print("Password adalah :  ", open_decrypt)
        
# Decrypt : metode yang digunakan untuk mengubah atau menerjemahkan file rahasia yang dienkripsi menjadi pesan asli
def decrypt(pswd):
    pswd_split = [(pswd[k:k+3]) for k in range(0, len(pswd), 3)]
    open_encrypt = ''.join(chr(((ord(list(z)[0])-80)*26)+(ord(list(z)[1])-80)) for z in pswd_split)
    # outputnya
    print("Passwordnya adalah :  ", open_encrypt)

# %% [markdown]
#  3.b. Apa output yang dihasilkan dari program tersebut jika input password adalah
# ‘anakanakcerdas2020’ ?
#
#  **jawab**

# %%
usr_input = input("Masukan password Anda : ")
encrypt(usr_input)
# Out:
# Masukan password Anda :  anakanakcerdas2020
# Password adalah :   Sc-TV-Sc-TS+Sc-TV-Sc-TS+Se-Sg-TZ-Sf-Sc-T[-Qh-Qf-Qh-Qf-

# %% [markdown]
# 3.c. (Bonus) User tersebut lupa password asli yang dia inputkan ke dalam program
# tersebut, password setelah dienkripsi adalah
# ‘Sc-TV-Sc-TS+T[-Sc-TQ+TV-T[-Sf-Sc-T\-Sc-Qh-Qf-Qh-Qf-TS+Sg-Se-Sg-’. Bantulah user
# tersebut mendapatkan password asli nya!
#
#  **jawab**

# %%
usr_input = input("Masukan password yang Anda ingin pecahkan : ")
decrypt(usr_input)
# Out:
# Masukan password yang Anda ingin pecahkan :  Sc-TV-Sc-TS+T[-Sc-TQ+TV-T[-Sf-Sc-T\-Sc-Qh-Qf-Qh-Qf-TS+Sg-Se-Sg-
# Passwordnya adalah :   anaksainsdata2020kece
